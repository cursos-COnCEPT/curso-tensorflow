# %% [markdown]
# # Hyperparamter tuning

# %% [markdown]
# ## Objetivos
# *
# *

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

import keras_tuner as kt

import numpy as np
import pandas as pd
from IPython import display
from matplotlib import pyplot as plt

import os

print(tf.__version__)
# Out:
# 2.18.0

# %% [markdown]
# ## Importación y pretratamiento de datos
# En esta demostración se va a utilizar de nuevo la base de datos *Wine Quality*, disponible en [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/dataset/186/wine+quality).

# %%
if 'google.colab' in str(get_ipython()):
  data_path = 'https://raw.githubusercontent.com/cursos-COnCEPT/curso-tensorflow/refs/heads/main/winequality-red.csv'
else:
  data_path = os.getcwd() + '\\winequality-red.csv'

red_wine = pd.read_csv(data_path, sep=';')
red_wine.tail()

# Split data
train_ratio = .7
val_ratio = .15
df_train = red_wine.sample(frac=train_ratio+val_ratio, random_state=0)
df_test = red_wine.drop(df_train.index)
df_valid = red_wine.sample(frac=val_ratio/(val_ratio+train_ratio), random_state=0)

# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
X_test = df_test.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']
y_test = df_test['quality']

# Scale to [0, 1]
max_ = X_train.max(axis=0)
min_ = X_train.min(axis=0)
X_train = (X_train - min_) / (max_ - min_)
X_valid = (X_valid - min_) / (max_ - min_)
X_test = (X_test - min_) / (max_ - min_)

# %% [markdown]
# ## Definición del modelo
#
# Cuando se construye un modelo para *hypertuning*, se definen tanto el espacio de búsqueda de hiperparámetros como la arquitectura del modelo. El modelo que configure para el hipertuning se denomina *hypermodel*.
#
# Aunque puede definirse un *hypermodel*, aquí lo haremos utilizando una función que sirva para construir el modelo. Esta función devolverá un modelo ya compilado donde que utiliza hiperparámetros en lugar de valores fijos para aquellos elementos que queramos "tunear".
#
# A continuación, ajusta el número de neuronas de la primera capa, que puede estar comprendido entre 16 y 128, variando en potencias de base 2. Además, escoge el valor óptimo para el learning rate entre las siguientes opciones [0.001, 0.005, 0.0001].

# %%
def model_builder(hp):
    hp_neurons = hp.Int('neurons', 
                        min_value=16, 
                        max_value=128, 
                        step=2, 
                        sampling='log')
    hp_learning_rate = hp.Choice('learning_rate', 
                                values=[1e-3, 5e-4, 1e-4])

    model = keras.Sequential([
        layers.Input(shape=[X_train.shape[1]]),
        layers.Dense(hp_neurons, activation='relu'),
        layers.Dense(16, activation='relu'),
        layers.Dense(1),
    ])

    optimizer = tf.keras.optimizers.Adam(hp_learning_rate)
    
    model.compile(optimizer=optimizer,loss='mae')

    return model

# %% [markdown]
# ## Ajuste de hiperparámetros
#
# En Keras hay cuatro métodos diferentes para realizar la búsqueda - `RandomSearch`, `Hyperband`, `BayesianOptimization`, y `Sklearn`. En este ejemplo se utiliza el método `Hyperband`.
#
# Este algoritmo es rápido y eficiente porque prueba varias combinaciones de opciones (como el número de capas o el *learning rate*) y asigna más recursos (tiempo de entrenamiento) a las opciones que están funcionando mejor, para así encontrar la mejor solución en menos tiempo.
#
# Para instanciar el *tuner*, hay que especificar el hipermodelo, el objetivo a optimizar y el número máximo de épocas a entrenar.

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=100,
                     overwrite=True)
                     
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 2, 'sampling': 'log'}
# learning_rate (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.001, 0.0005, 0.0001], 'ordered': True}

# %% [markdown]
# Crea un callback tipo `EarlyStopping` antes de efectuar la búsqueda.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss', # what to track
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %% [markdown]
# Efectúa la búsqueda, conocida como *hyperparameter tuning* con el comando `tuner.search`. Esta función utiliza los mismos argumentos que el método `model.fit`.

# %%
tuner.search(X_train, y_train,
            epochs=100,
            validation_data=(X_valid, y_valid), 
            batch_size=256,
            callbacks=[early_stopping],
            verbose='auto')

# Extraer la mejor combinación de hiperparámetros
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
El número de neuronas óptimo en la primera capa es {best_hps.get('neurons')} \n y el valor óptimo para el learning rate es {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 12 Complete [00h 00m 03s]
# val_loss: 5.527632713317871
#
# Best val_loss So Far: 4.859363079071045
# Total elapsed time: 00h 00m 35s
#
# El número de neuronas óptimo en la primera capa es 64
#  y el valor óptimo para el learning rate es 0.001.

# %% [markdown]
# ## Entrenamiento y evaluación del modelo
#
# Crea una nueva instancia del modelo utilizando la mejor configuración de los hiperparámetros y lleva a cabo el entrenamiento.

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train, y_train, 
                    epochs=200,
                    validation_data=(X_valid, y_valid), 
                    batch_size=256,
                    callbacks=[early_stopping],
                    verbose='auto')
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 5.6243 - val_loss: 5.4588
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 5.4552 - val_loss: 5.3171
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.3022 - val_loss: 5.1665
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 5.1596 - val_loss: 4.9897
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.9572 - val_loss: 4.7672
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.7297 - val_loss: 4.4893
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4246 - val_loss: 4.1464
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.0940 - val_loss: 3.7052
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.6068 - val_loss: 3.1278
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.9660 - val_loss: 2.4008
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2215 - val_loss: 1.5592
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.3674 - val_loss: 0.8314
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.8258 - val_loss: 0.8194
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.8638 - val_loss: 0.8727
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.8853 - val_loss: 0.7652
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7942 - val_loss: 0.7157
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.7633 - val_loss: 0.7192
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.7360 - val_loss: 0.7022
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.7294 - val_loss: 0.6912
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7190 - val_loss: 0.6864
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.7179 - val_loss: 0.6773
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.7073 - val_loss: 0.6668
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6973 - val_loss: 0.6579
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6931 - val_loss: 0.6504
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6784 - val_loss: 0.6434
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.6799 - val_loss: 0.6351
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6867 - val_loss: 0.6278
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6730 - val_loss: 0.6181
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6685 - val_loss: 0.6097
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6573 - val_loss: 0.6025
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6597 - val_loss: 0.5949
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6320 - val_loss: 0.5871
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6345 - val_loss: 0.5809
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6287 - val_loss: 0.5778
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6245 - val_loss: 0.5739
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6204 - val_loss: 0.5676
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6071 - val_loss: 0.5651
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6065 - val_loss: 0.5627
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6083 - val_loss: 0.5600
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5992 - val_loss: 0.5585
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6049 - val_loss: 0.5573
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5993 - val_loss: 0.5565
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6210 - val_loss: 0.5533
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.
# Epoch 131/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5010 - val_loss: 0.4577
# Epoch 132/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4918 - val_loss: 0.4554
# Epoch 133/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4769 - val_loss: 0.4570
# Epoch 134/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4863 - val_loss: 0.4547
# Epoch 135/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4974 - val_loss: 0.4589
# Epoch 136/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4852 - val_loss: 0.4544
# Epoch 137/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4928 - val_loss: 0.4533
# Epoch 138/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4842 - val_loss: 0.4532
# Epoch 139/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4882 - val_loss: 0.4530
# Epoch 140/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4965 - val_loss: 0.4541
# Epoch 141/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4829 - val_loss: 0.4526
# Epoch 142/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4830 - val_loss: 0.4577
# Epoch 143/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4958 - val_loss: 0.4515
# Epoch 144/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.5036 - val_loss: 0.4527
# Epoch 145/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4981 - val_loss: 0.4535
# Epoch 146/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.4944 - val_loss: 0.4511
# Epoch 147/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4897 - val_loss: 0.4530
# Epoch 148/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4883 - val_loss: 0.4515
# Epoch 149/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4856 - val_loss: 0.4505
# Epoch 150/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4870 - val_loss: 0.4517
# Epoch 151/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4799 - val_loss: 0.4514
# Epoch 152/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4855 - val_loss: 0.4492
# Epoch 153/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4954 - val_loss: 0.4521
# Epoch 154/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4906 - val_loss: 0.4483
# Epoch 155/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4891 - val_loss: 0.4509
# Epoch 156/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4971 - val_loss: 0.4496
# Epoch 157/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4814 - val_loss: 0.4482
# Epoch 158/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4771 - val_loss: 0.4508
# Epoch 159/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4817 - val_loss: 0.4485
# Epoch 160/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4963 - val_loss: 0.4485
# Epoch 161/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4794 - val_loss: 0.4472
# Epoch 162/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4753 - val_loss: 0.4466
# Epoch 163/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4864 - val_loss: 0.4502
# Epoch 164/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4801 - val_loss: 0.4460
# Epoch 165/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4759 - val_loss: 0.4468
# Epoch 166/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4911 - val_loss: 0.4485
# Epoch 167/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4831 - val_loss: 0.4462
# Epoch 168/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4712 - val_loss: 0.4501
# Epoch 169/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4840 - val_loss: 0.4464
# Epoch 170/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4764 - val_loss: 0.4469
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4912 - val_loss: 0.4455
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4774 - val_loss: 0.4464
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4782 - val_loss: 0.4464
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4815 - val_loss: 0.4537
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4867 - val_loss: 0.4451
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4732 - val_loss: 0.4501
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.4834 - val_loss: 0.4442
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4841 - val_loss: 0.4503
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4805 - val_loss: 0.4437
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4753 - val_loss: 0.4435
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4816 - val_loss: 0.4461
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4782 - val_loss: 0.4435
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4857 - val_loss: 0.4445
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4926 - val_loss: 0.4428
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4876 - val_loss: 0.4461
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4755 - val_loss: 0.4425
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4820 - val_loss: 0.4425
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4715 - val_loss: 0.4428
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4826 - val_loss: 0.4451
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4763 - val_loss: 0.4425
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4715 - val_loss: 0.4422
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4776 - val_loss: 0.4431
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4757 - val_loss: 0.4412
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4790 - val_loss: 0.4420
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4681 - val_loss: 0.4403
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4694 - val_loss: 0.4448
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4734 - val_loss: 0.4406
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4603 - val_loss: 0.4444
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4774 - val_loss: 0.4426
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4774 - val_loss: 0.4432

# %% [markdown]
# A continuación, evalúa la calidad del ajuste del modelo.

# %%
eval_result = model.evaluate(X_test, y_test)
print("MAE:", eval_result)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4514
# MAE: 0.4729171693325043

# %% [markdown]
# ## Conclusiones
# Este ejercicio no ha sido más que una introducción muy breve al tuneado de hiperparámetros. Para aprender más sobre el Keras Tuner, échale un vistazo a estos recursos:
#
# * [Keras Tuner en el blog de TensorFlow](https://blog.tensorflow.org/2020/01/hyperparameter-tuning-with-keras-tuner.html)
# * [Sitio web del Sintonizador Keras](https://keras-team.github.io/keras-tuner/)
