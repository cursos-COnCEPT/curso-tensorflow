# %% [markdown]
# # Hyperparamter tuning

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

import keras_tuner as kt

import numpy as np
import pandas as pd
from IPython import display
from matplotlib import pyplot as plt

import os

print(tf.__version__)
# Out:
# 2.18.0

# %% [markdown]
# ## Importación y pretratamiento de datos
# En esta demostración se va a utilizar de nuevo la base de datos de la central de ciclo combinado.

# %%
if 'google.colab' in str(get_ipython()):
  dataset_path = 'https://raw.githubusercontent.com/cursos-COnCEPT/curso-tensorflow/refs/heads/main/CCP.csv'
else:
  dataset_path = os.getcwd() + '\\CCP.csv'

raw_dataset = pd.read_csv(dataset_path)
dataset = raw_dataset.copy()
dataset.head()

# Split data
train_ratio = .7
val_ratio = .15
df = dataset.sample(frac=train_ratio+val_ratio, random_state=10)
df_test = dataset.drop(df.index)
df_train = df.sample(frac=val_ratio/(val_ratio+train_ratio), random_state=10)
df_valid = df.drop(df_train.index)

# Split features and target
X_train = df_train.drop('PE', axis=1)
X_valid = df_valid.drop('PE', axis=1)
X_test = df_test.drop('PE', axis=1)
y_train = df_train['PE']
y_valid = df_valid['PE']
y_test = df_test['PE']

# Scale to [0, 1]
max_ = X_train.max(axis=0)
min_ = X_train.min(axis=0)
X_train = (X_train - min_) / (max_ - min_)
X_valid = (X_valid - min_) / (max_ - min_)
X_test = (X_test - min_) / (max_ - min_)

# %% [markdown]
# ## 1- Definición del modelo
#
# Cuando se construye un modelo para *hypertuning*, se definen tanto el espacio de búsqueda de hiperparámetros como la arquitectura del modelo. El modelo que considera rangos de valores para los hiperparámetros en lugar de valores concretos se denomina *hypermodel*.
#
# Aunque hay diferentes alternativas para construir un *hypermodel*, aquí lo haremos utilizando una función, que devolverá un modelo ya compilado.
#
# A continuación, ajusta el número de neuronas de la primera capa, que puede estar comprendido entre 16 y 128, variando en potencias de base 2. Además, escoge el valor óptimo para el learning rate entre las siguientes opciones [0.001, 0.005, 0.0001].

# %%
def model_builder(hp):
    # Define los hiperparámetros
    hp_neurons = # TODO
    hp_learning_rate = # TODO

    # Define el modelo
    model = # TODO

    # Define el optimizador, utilizando Adam como algorimto de optimización y utilizando el valor de learning rate definido en los hiperparámetros
    optimizer = # TODO
    
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

    return model

# %% [markdown]
# ## 2- Ajuste de hiperparámetros
#
# En Keras hay cuatro métodos diferentes para realizar la búsqueda - `RandomSearch`, `Hyperband`, `BayesianOptimization`, y `Sklearn`. En este ejemplo se utiliza el método `Hyperband`.
#
# Este algoritmo es rápido y eficiente porque prueba varias combinaciones de opciones (como el número de capas o el *learning rate*) y asigna más recursos (tiempo de entrenamiento) a las opciones que están funcionando mejor, para así encontrar la mejor solución en menos tiempo.
#
# Para instanciar el *tuner*, hay que especificar el hipermodelo, el objetivo a optimizar y el número máximo de épocas a entrenar.

# %%
# Crea una instancia del tuner
tuner = kt.Hyperband(_______________ , # Indica la función que construye el modelo
                     objective= _____________ , # Indica la métrica a optimizar
                     max_epochs= _______________ , # Indica el número máximo de épocas por cada configuración exploarada
                     overwrite=True)

# Visualiza el resumen del espacio de búsqueda                    
# TODO
# Out:
# Search space summary
# Default search space size: 2
# neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 2, 'sampling': 'log'}
# learning_rate (Choice)
# {'default': 0.001, 'conditions': [], 'values': [0.001, 0.0005, 0.0001], 'ordered': True}

# %% [markdown]
# Crea un callback tipo `EarlyStopping` antes de efectuar la búsqueda.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
                        monitor= ______________ , # Métrica para "vigilar"
                        min_delta=______________, # Diferencia mínima a considerar como mejora
                        patience=______________, # Épocas a esperar antes de detener el entrenamiento desde que se deja de mejorar
                        restore_best_weights=True,
                    )

# %% [markdown]
# Efectúa la búsqueda, conocida como *hyperparameter tuning* con el comando `tuner.search`. Esta función utiliza los mismos argumentos que el método `model.fit`.

# %%
tuner.search(__________________ , # Completa con el conjunto de inputs de entrenamiento ya normalizadas
             __________________ , # Completa con las outputs del conjunto de datos de entrenamiento
            epochs= ____________________ , # Completa con el número de épocas
            batch_size = ___________________ , # Completa con el tamaño del batch
            validation_data =  __________________ , # Completa con el conjunto de inputs de validación ya normalizadas en forma de tupla (X,y)
            callbacks=[early_stopping],
            verbose='auto')

# Extraer la mejor combinación de hiperparámetros
best_hps= # TODO

print(f"""
El número de neuronas óptimo en la primera capa es {best_hps.get('neurons')} \n y el valor óptimo para el learning rate es {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 12 Complete [00h 00m 02s]
# val_loss: 454.1022033691406
#
# Best val_loss So Far: 448.1781311035156
# Total elapsed time: 00h 00m 32s
#
# El número de neuronas óptimo en la primera capa es 64
#  y el valor óptimo para el learning rate es 0.001.

# %% [markdown]
# ## 3- Entrenamiento y evaluación del modelo
#
# Crea una nueva instancia del modelo utilizando la mejor configuración de los hiperparámetros y lleva a cabo el entrenamiento.

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train, y_train, 
                    epochs=200,
                    validation_data=(X_valid, y_valid), 
                    batch_size=256,
                    callbacks=[early_stopping],
                    verbose='auto')
# Out:
# Epoch 1/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 454.2691 - val_loss: 453.3639
# Epoch 2/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 452.5218 - val_loss: 450.4492
# Epoch 3/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 449.2574 - val_loss: 443.7939
# Epoch 4/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 440.9043 - val_loss: 431.2198
# Epoch 5/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 426.4490 - val_loss: 410.0909
# Epoch 6/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 402.5386 - val_loss: 377.9478
# Epoch 7/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 367.4131 - val_loss: 332.1995
# Epoch 8/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 317.9408 - val_loss: 269.8278
# Epoch 9/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 250.1926 - val_loss: 188.2901
# Epoch 10/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 163.1480 - val_loss: 86.1723
# Epoch 11/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68.6296 - val_loss: 51.5347
# Epoch 12/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51.9240 - val_loss: 49.5799
# Epoch 13/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 49.3133 - val_loss: 47.6025
# Epoch 14/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.7620 - val_loss: 45.5897
# Epoch 15/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.6331 - val_loss: 43.6287
# Epoch 16/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 43.8695 - val_loss: 41.7651
# Epoch 17/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.4850 - val_loss: 40.0967
# Epoch 18/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.2025 - val_loss: 38.5991
# Epoch 19/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.6856 - val_loss: 37.2685
# Epoch 20/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.3667 - val_loss: 36.1065
# Epoch 21/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.2207 - val_loss: 35.0971
# Epoch 22/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.5254 - val_loss: 34.2458
# Epoch 23/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.3180 - val_loss: 33.4868
# Epoch 24/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.7599 - val_loss: 32.7934
# Epoch 25/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.6873 - val_loss: 32.1613
# Epoch 26/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.8252 - val_loss: 31.5710
# Epoch 27/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.7683 - val_loss: 31.0234
# Epoch 28/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.5334 - val_loss: 30.4982
# Epoch 29/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.2630 - val_loss: 30.0321
# Epoch 30/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.7452 - val_loss: 29.5250
# Epoch 31/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.7554 - val_loss: 29.0900
# Epoch 32/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.5926 - val_loss: 28.6026
# Epoch 33/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.8927 - val_loss: 28.1410
# Epoch 34/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.1959 - val_loss: 27.6878
# Epoch 35/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.0740 - val_loss: 27.2661
# Epoch 36/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.3634 - val_loss: 26.7805
# Epoch 37/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.1050 - val_loss: 26.3666
# Epoch 38/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.7174 - val_loss: 25.8942
# Epoch 39/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.4157 - val_loss: 25.5037
# Epoch 40/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.6362 - val_loss: 24.9285
# Epoch 41/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.2443 - val_loss: 24.4816
# Epoch 42/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.8118 - val_loss: 23.9504
# Epoch 43/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.2725 - val_loss: 23.4649
# Epoch 44/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.5268 - val_loss: 22.9579
# Epoch 45/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.7314 - val_loss: 22.4435
# Epoch 46/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.7081 - val_loss: 21.9479
# Epoch 47/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.5898 - val_loss: 21.4169
# Epoch 48/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.6403 - val_loss: 20.8748
# Epoch 49/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.0610 - val_loss: 20.3401
# Epoch 50/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.5947 - val_loss: 19.8016
# Epoch 51/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.0211 - val_loss: 19.2461
# Epoch 52/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.4846 - val_loss: 18.6861
# Epoch 53/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.0253 - val_loss: 18.1316
# Epoch 54/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.3833 - val_loss: 17.5769
# Epoch 55/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.9850 - val_loss: 17.0098
# Epoch 56/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.2561 - val_loss: 16.4666
# Epoch 57/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.7790 - val_loss: 15.9030
# Epoch 58/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.3058 - val_loss: 15.3301
# Epoch 59/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.6858 - val_loss: 14.7652
# Epoch 60/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.1762 - val_loss: 14.2070
# Epoch 61/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.7033 - val_loss: 13.6579
# Epoch 62/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.1854 - val_loss: 13.1094
# Epoch 63/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.4984 - val_loss: 12.5902
# Epoch 64/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.0721 - val_loss: 12.0972
# Epoch 65/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.6255 - val_loss: 11.5532
# Epoch 66/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.2845 - val_loss: 11.0473
# Epoch 67/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.6494 - val_loss: 10.5396
# Epoch 68/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.2060 - val_loss: 10.0352
# Epoch 69/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5995 - val_loss: 9.5678
# Epoch 70/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2438 - val_loss: 9.1003
# Epoch 71/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7701 - val_loss: 8.6838
# Epoch 72/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2727 - val_loss: 8.2132
# Epoch 73/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9181 - val_loss: 7.7621
# Epoch 74/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4858 - val_loss: 7.3845
# Epoch 75/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1196 - val_loss: 6.9547
# Epoch 76/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6688 - val_loss: 6.5542
# Epoch 77/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3211 - val_loss: 6.2005
# Epoch 78/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0108 - val_loss: 5.8575
# Epoch 79/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6253 - val_loss: 5.5445
# Epoch 80/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3623 - val_loss: 5.3298
# Epoch 81/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0039 - val_loss: 4.9917
# Epoch 82/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8740 - val_loss: 4.7543
# Epoch 83/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6137 - val_loss: 4.5939
# Epoch 84/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4401 - val_loss: 4.3982
# Epoch 85/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2873 - val_loss: 4.2711
# Epoch 86/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1661 - val_loss: 4.1371
# Epoch 87/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0081 - val_loss: 4.0427
# Epoch 88/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9162 - val_loss: 3.9825
# Epoch 89/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8564 - val_loss: 3.9287
# Epoch 90/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8284 - val_loss: 3.8844
# Epoch 91/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8103 - val_loss: 3.8656
# Epoch 92/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7721 - val_loss: 3.8379
# Epoch 93/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7650 - val_loss: 3.8186
# Epoch 94/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7024 - val_loss: 3.8194
# Epoch 95/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7073 - val_loss: 3.8300
# Epoch 96/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7357 - val_loss: 3.7830
# Epoch 97/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7586 - val_loss: 3.7720
# Epoch 98/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7026 - val_loss: 3.7829
# Epoch 99/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6843 - val_loss: 3.7770
# Epoch 100/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7646 - val_loss: 3.7574
# Epoch 101/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6453 - val_loss: 3.7608
# Epoch 102/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7021 - val_loss: 3.7501
# Epoch 103/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6440 - val_loss: 3.7823
# Epoch 104/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6910 - val_loss: 3.7711
# Epoch 105/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6510 - val_loss: 3.7403
# Epoch 106/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6758 - val_loss: 3.7534
# Epoch 107/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6888 - val_loss: 3.7224
# Epoch 108/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6249 - val_loss: 3.7338
# Epoch 109/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6839 - val_loss: 3.7140
# Epoch 110/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6199 - val_loss: 3.8238
# Epoch 111/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7033 - val_loss: 3.7838
# Epoch 112/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6929 - val_loss: 3.7252
# Epoch 113/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6161 - val_loss: 3.6994
# Epoch 114/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6333 - val_loss: 3.7121
# Epoch 115/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6542 - val_loss: 3.7122
# Epoch 116/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6532 - val_loss: 3.8381
# Epoch 117/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6997 - val_loss: 3.6890
# Epoch 118/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6270 - val_loss: 3.6893
# Epoch 119/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6163 - val_loss: 3.6861
# Epoch 120/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6235 - val_loss: 3.7366
# Epoch 121/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6540 - val_loss: 3.8207
# Epoch 122/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6766 - val_loss: 3.7039
# Epoch 123/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6439 - val_loss: 3.8063
# Epoch 124/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6405 - val_loss: 3.6810
# Epoch 125/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6387 - val_loss: 3.7018
# Epoch 126/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6214 - val_loss: 3.6730
# Epoch 127/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6338 - val_loss: 3.7606
# Epoch 128/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6320 - val_loss: 3.6979
# Epoch 129/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5836 - val_loss: 3.6745
# Epoch 130/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6483 - val_loss: 3.6646
# Epoch 131/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6119 - val_loss: 3.7602
# Epoch 132/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6104 - val_loss: 3.7111
# Epoch 133/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5981 - val_loss: 3.6641
# Epoch 134/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5517 - val_loss: 3.6599
# Epoch 135/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5964 - val_loss: 3.6736
# Epoch 136/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6559 - val_loss: 3.6672
# Epoch 137/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6586 - val_loss: 3.6580
# Epoch 138/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5458 - val_loss: 3.6569
# Epoch 139/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5975 - val_loss: 3.7334
# Epoch 140/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6070 - val_loss: 3.6615
# Epoch 141/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5925 - val_loss: 3.7051
# Epoch 142/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5893 - val_loss: 3.6698
# Epoch 143/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6770 - val_loss: 3.6538
# Epoch 144/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6150 - val_loss: 3.6676
# Epoch 145/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6271 - val_loss: 3.6507
# Epoch 146/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6000 - val_loss: 3.6490
# Epoch 147/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6070 - val_loss: 3.6988
# Epoch 148/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6074 - val_loss: 3.7159
# Epoch 149/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6187 - val_loss: 3.6502
# Epoch 150/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6272 - val_loss: 3.6542
# Epoch 151/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5899 - val_loss: 3.6494
# Epoch 152/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5866 - val_loss: 3.6522
# Epoch 153/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5750 - val_loss: 3.6678
# Epoch 154/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7198 - val_loss: 3.6874
# Epoch 155/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6075 - val_loss: 3.6768
# Epoch 156/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5697 - val_loss: 3.6423
# Epoch 157/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5938 - val_loss: 3.6498
# Epoch 158/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6127 - val_loss: 3.6410
# Epoch 159/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6047 - val_loss: 3.6400
# Epoch 160/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5923 - val_loss: 3.6393
# Epoch 161/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6021 - val_loss: 3.6480
# Epoch 162/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5282 - val_loss: 3.6860
# Epoch 163/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6209 - val_loss: 3.7203
# Epoch 164/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6033 - val_loss: 3.6378
# Epoch 165/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5899 - val_loss: 3.6501
# Epoch 166/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5760 - val_loss: 3.7062
# Epoch 167/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6074 - val_loss: 3.6508
# Epoch 168/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5763 - val_loss: 3.6711
# Epoch 169/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5963 - val_loss: 3.6354
# Epoch 170/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5596 - val_loss: 3.6497
# Epoch 171/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6172 - val_loss: 3.6356
# Epoch 172/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5608 - val_loss: 3.6343
# Epoch 173/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5009 - val_loss: 3.7014
# Epoch 174/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6046 - val_loss: 3.6760
# Epoch 175/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6243 - val_loss: 3.6353
# Epoch 176/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6433 - val_loss: 3.6318
# Epoch 177/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5710 - val_loss: 3.6316
# Epoch 178/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5796 - val_loss: 3.6325
# Epoch 179/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5650 - val_loss: 3.6313
# Epoch 180/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6106 - val_loss: 3.6880
# Epoch 181/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6029 - val_loss: 3.6404
# Epoch 182/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6168 - val_loss: 3.6355
# Epoch 183/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5947 - val_loss: 3.6337
# Epoch 184/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6077 - val_loss: 3.6371
# Epoch 185/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5416 - val_loss: 3.6302
# Epoch 186/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5859 - val_loss: 3.6259
# Epoch 187/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6293 - val_loss: 3.6740
# Epoch 188/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5499 - val_loss: 3.6299
# Epoch 189/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5650 - val_loss: 3.7262
# Epoch 190/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6312 - val_loss: 3.7570
# Epoch 191/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6143 - val_loss: 3.6475
# Epoch 192/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5437 - val_loss: 3.6490
# Epoch 193/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5545 - val_loss: 3.6306
# Epoch 194/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5813 - val_loss: 3.6584
# Epoch 195/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5724 - val_loss: 3.6366
# Epoch 196/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6035 - val_loss: 3.7280
# Epoch 197/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5540 - val_loss: 3.6650
# Epoch 198/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5863 - val_loss: 3.6292
# Epoch 199/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6477 - val_loss: 3.6261
# Epoch 200/200
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6421 - val_loss: 3.6313

# %% [markdown]
# A continuación, evalúa la calidad del ajuste del modelo.

# %%
eval_result = model.evaluate(X_test, y_test)
print("MAE:", eval_result)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5499
# MAE: 3.59546160697937

# %% [markdown]
# ## Conclusión
# Este ejercicio no ha sido más que una introducción muy breve al tuneado de hiperparámetros. Para aprender más sobre `Keras Tuner`, puedes consultar estos recursos:
#
# * [Keras Tuner en el blog de TensorFlow](https://blog.tensorflow.org/2020/01/hyperparameter-tuning-with-keras-tuner.html)
# * [Sitio web del Sintonizador Keras](https://keras-team.github.io/keras-tuner/)
